# %%
name="kavya"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# **data types**

# %%
name2="kav & 123"
print(type(name2))
# Out:
# <class 'str'>

# %%
num1=69
num2=56.89
num3=4j
num4=-99
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# Sequence data types
# Lists
# Tuples
# range
#
# 1.Ordered
# 2.Mutable
# 3.Allow duplicates

# %%
lis=['kav','123','30.45']
type(lis)
# Out:
# list

# %%
print(lis)
# Out:
# ['kav', '123', '30.45']

# %%
lis2= ['apple','200','India']
print(len(lis))
print(len(lis2))
lis3=lis+ lis2
print(lis3)
print(len(lis3))
# Out:
# 3
# 3
# ['kav', '123', '30.45', 'apple', '200', 'India']
# 6

# %%
lis2.append(" Hubli")

# %%
lis2
# Out:
# ['apple', '200', 'India', 'Hubli']

# %%
lis2.append("kavya")
lis2
# Out:
# ['apple', '200', 'India', 'Hubli', 'kavya', 'kavya']

# %%
lis2.clear()

# %%
lis2
# Out:
# []

# %%
lis=['jk','aa','kle','jjj']
lis[0]
# Out:
# 'jk'

# %%
lis.sort()

# %%
lis
# Out:
# ['aa', 'jjj', 'jk', 'kle']

# %%
tuple1=("Hubli","Belgaum","Hubli")
print(type(tuple1))
tuple2=("Hubli",)
print(type(tuple2))
tuple3=(1,2,3,4,5)
print(type(tuple3))
tuple4=("asdf","123",1,1,2,3,5,True)
print(type(tuple4))

tuple5=tuple((1,2,3,4,5))
print(type(tuple5))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# Tuples-->storing multiple items in a single variable
# 1.Ordered
# 2.Unchanged
# 3.Allow duplicate
#
#
# 1.How do we access elements in the tuple?
# 2.Join tuples
# 3.Multiply tuples
# 4.Indexing
# 5.count

# %%
tuple1=("Hubli","Belgaum","Hubli")
print(tuple1[0])
# Out:
# Hubli

# %%
tuple1=("Hubli","Belgaum","Hubli")
print(tuple[0])
print(tuple[1])
print(tuple[2])
# Out:
# tuple[0]
# tuple[1]
# tuple[2]

# %%
tuple1=("Hubli","Belgaum","Hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-1])
tuple6= tuple1+ tuple1
print(tuple6)
tuple7=tuple6 * 2
print(tuple7)

y= tuple7.index('Hubli')
print(y)

x= tuple7.count('Hubli')
print(x)
# Out:
# Hubli
# Belgaum
# Hubli
# Hubli
# ('Hubli', 'Belgaum', 'Hubli', 'Hubli', 'Belgaum', 'Hubli')
# ('Hubli', 'Belgaum', 'Hubli', 'Hubli', 'Belgaum', 'Hubli', 'Hubli', 'Belgaum', 'Hubli', 'Hubli', 'Belgaum', 'Hubli')
# 0
# 8

# %%
x= ("Hubli","Belgaum","Blore")
print(type(x))
# Out:
# <class 'tuple'>

# %%
set1={"Red","Blue","Black","Red"}
print(set1)
set1.add('orange')
print(set1)
set2={"ball","bat","wicket"}
set1.update(set2)
print(set1)
# Out:
# {'Black', 'Red', 'Blue'}
# {'orange', 'Black', 'Red', 'Blue'}
# {'ball', 'wicket', 'Black', 'Blue', 'bat', 'Red', 'orange'}

# %% [markdown]
# sets
#
#
# 1.Unordered
# 2.Unchangeable
# 3.Duplicates not allowed

# %% [markdown]
# Dictories data type

# %%
Dict1= {"Name":"Kavya",
      "Age":"20",
      "Gender":"Female","Year":"2022","Year":"2015"}
print(Dict1)
# Out:
# {'Name': 'Kavya', 'Age': '20', 'Gender': 'Female', 'Year': '2015'}

# %%
print(type(Dict1))
# Out:
# <class 'dict'>

# %%
dict2= dict(fruit= "Banana",Dessert="Ice")
print(dict2)
print(type(dict2))
# Out:
# {'fruit': 'Banana', 'Dessert': 'Ice'}
# <class 'dict'>
