# %% [markdown]
# # Linear regression
#
# 1.scikit learn
# 2.stats models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,9,12,14,18])

# %%
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR=LinearRegression()

# %%
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=SLR.predict(x)

# %%
from  sklearn.metrics import mean_squared_error

mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')

print("MSE:", mse)
print("intercept:",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# MSE: 0.5056719506337065
# intercept: 3.938587739718434
# slope: [0.31193881]

# %%
import random
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


random.seed(42)
num_points = 50
x = [random.uniform(0, 10) for _ in range(num_points)]
y = [2 * xi + 3 + random.gauss(0, 1) for xi in x]  # y = 2x + 3 + noise


x = np.array(x).reshape(-1, 1)
y = np.array(y)


model = LinearRegression()


model.fit(x, y)


y_pred = model.predict(x)


plt.scatter(x, y, label='Original data')
plt.plot(x, y_pred, color='red', label='Regression line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression')
plt.show()


print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope (Coefficient): 1.95362549182
# Intercept: 3.383439875656032

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Read the Excel file
excel_file = "import pandas as pd"
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Read the Excel file
excel_file = "path/to/your/excel/file.xlsx"
data = pd.read_excel(excel_file)

# Assuming your Excel columns are named 'x' and 'y'
x = data['x'].values.reshape(-1, 1)
y = data['y'].values

# Create a linear regression model
model = LinearRegression()
model.fit(x, y)

# Predict y values using the model
y_pred = model.predict(x)

# Plot the original data and the regression line
plt.scatter(x, y, label='Original Data')
plt.plot(x, y_pred, color='red', label='Linear Regression')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear Regression')
plt.legend()
plt.show()

# Print the slope (coefficients) and intercept of the regression line
print("Slope:", model.coef_[0])
print("Intercept:" , model.intercept_)"
data = pd.read_excel('/content/drive/MyDrive/machine learning.xlsx')

# Assuming your Excel columns are named 'x' and 'y'
x = data['x'].values.reshape(-1, 1)
y = data['y'].values

# Create a linear regression model
model = LinearRegression()
model.fit(x, y)

# Predict y values using the model
y_pred = model.predict(x)

# Plot the original data and the regression line
plt.scatter(x, y, label='Original Data')
plt.plot(x, y_pred, color='red', label='Linear Regression')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Linear Regression')
plt.legend()
plt.show()

# Print the slope (coefficients) and intercept of the regression line
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
#   File "<ipython-input-1-4f5f319de471>", line 38
#     print("Intercept:" , model.intercept_)"
#                                           ^
# SyntaxError: unterminated string literal (detected at line 38)

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt

x=np.array([])
y=np.array([])
n=int(input("enter the range"))
for i in range(1,n):
  z=random.randint(1,10)
  t=random.randint(1,10)
  x=np.append(x,z)
  y=np.append(y,t)
print(x)
print(y)
x=x.reshape((-1,1))
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()
# Out:
# enter the range9
# [ 2.  4. 10.  9.  6.  1.  7. 10.]
# [ 3.  6.  7.  3.  5. 10.  7.  8.]
