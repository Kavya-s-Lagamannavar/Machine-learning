# %% [markdown]
# *My first program*

# %%
print("I am kavya")
# Out:
# I am kavya

# %%
a+b

# %% [markdown]
# ***variable declarartion in python***
#
# Rule 1: variable should start from alphabet or _
# Rule 2: variable should not start with some numbers or special characters Ex:1stnum=5
# Rule 3 : varible declaration is special sensitive
# Name name namE
# Name=90
# namE=70

# %%
a=5
b=4
sum=a+b
print(sum)
print("sum")
# Out:
# 9
# sum

# %%
a-b
# Out:
# 1

# %% [markdown]
# ***variable declaration in Python***

# %%
a=5
b=3
diff=a-b
print(diff)
print("diff")
# Out:
# 2
# diff

# %% [markdown]
# dif=a-b-c

# %% [markdown]
# **variable declaration in Python**

# %%
a=500
b=100
c=200
dif=a-b-c
print(dif)
# Out:
# 200

# %%
mul=a*b

# %% [markdown]
# ***variable declaration in Python***

# %%
a=2
b=3
mul=a*b
print(mul)
print("mul")
# Out:
# 6
# mul

# %%
div=a/b

# %% [markdown]
# ***variable declaration in Python***

# %%
a=50
b=10
div=a/b
print(div)
print("div")
# Out:
# 5.0
# div

# %%
div1=a%b

# %% [markdown]
# **variable declaration in python**

# %%
from binascii import b2a_base64
a=140
b=7
div1=a%b
print(div1)
# Out:
# 0

# %%
squ=a*a

# %% [markdown]
# variable declaration in python

# %%
a=2
squ=a*a
print(squ)
# Out:
# 4

# %% [markdown]
# sroot=a**0.5

# %% [markdown]
# variable declaration in python

# %%
a=9
sroot=a**0.5
print(sroot)
# Out:
# 3.0

# %% [markdown]
# # ***diff of 2 square nos***

# %%
a=10
b=5
diff=(a*a)-(b*b)
print(diff)
# Out:
# 75
